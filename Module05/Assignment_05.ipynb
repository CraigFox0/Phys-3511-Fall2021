# %% [markdown]
# # Assignment 5:  Due 10/6
#
# In this assignment you will become familiar with the Pandas library through the exploration of a Nobel prize data set.
#
# This data set was taken from the Kaggle website (https://www.kaggle.com/). If you are interested in data science and / or analysis, this website offers tons of data sets in various formats that you can access. They even post compititions that you can enter, some with money prizes awarded.
#
# The libraries needed for this assignment are listed below.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %% [markdown]
# # 1a)
#
# Read in the data set 'data/nobel.csv' into a DataFrame using Pandas .

# %%
data = pd.read_csv('data/nobel.csv')

# %% [markdown]
# # 1b)
#
# Display below the output from the DataFrame functions *info*.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 911 entries, 0 to 910
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  911 non-null    int64
#  1   category              911 non-null    object
#  2   prize                 911 non-null    object
#  3   motivation            823 non-null    object
#  4   prize_share           911 non-null    object
#  5   laureate_id           911 non-null    int64
#  6   laureate_type         911 non-null    object
#  7   full_name             911 non-null    object
#  8   birth_date            883 non-null    object
#  9   birth_city            883 non-null    object
#  10  birth_country         885 non-null    object
#  11  sex                   885 non-null    object
#  12  organization_name     665 non-null    object
#  13  organization_city     667 non-null    object
#  14  organization_country  667 non-null    object
# ...

# %% [markdown]
# # 1c)
#
# Show the first 5 listings of the dataset.

# %%
data.head()
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           motivation prize_share  laureate_id  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
#
#   laureate_type                     full_name  birth_date         birth_city  \
# ...

# %% [markdown]
# # Problem 2
#
# How many null ('NaN') values there are in each *category*? What is the total number of Null values in the DataFrame?

# %%
data.isna().sum()
# Out:
# year                      0
# category                  0
# prize                     0
# motivation               88
# prize_share               0
# laureate_id               0
# laureate_type             0
# full_name                 0
# birth_date               28
# birth_city               28
# birth_country            26
# sex                      26
# organization_name       246
# organization_city       244
# organization_country    244
# death_date              318
# death_city              335
# death_country           329
# dtype: int64

# %%
print('The total is {}'.format(data.isna().sum().sum()))
# Out:
# The total is 1912

# %% [markdown]
# # Problem 3
#
# Make a histogram of the number of nobel prizes awarded per year. Around which decade (1900, 1910, 1920, ...) were the least amount of prizes awarded?

# %%
data.hist('year', bins = 20)
print('The least amount of nobel prizes was awarded in the 1910s closely followed by the 1940s')
# Out:
# <img src="data:image/png;base64,..." width="640">
# The least amount of nobel prizes was awarded in the 1910s closely followed by the 1940s

# %% [markdown]
# # Problem 4
#
# Use groupby method to printout the number of prizes awarded to each category. Which category has the most prizes?

# %%
data.groupby('category').count()['prize']
# Out:
# category
# Chemistry     175
# Economics      78
# Literature    113
# Medicine      211
# Peace         130
# Physics       204
# Name: prize, dtype: int64

# %%
print('Medicine has the most prizes')
# Out:
# Medicine has the most prizes

# %% [markdown]
# # Problem 5
#
# Find percentage of the prizes were awarded to 1, 2, 3, and 4 people? Meaning what percentage of 1/1, 1/2, 1/3, and 1/4 prize_shares are there?

# %%
prizes_by_share = data.groupby('prize_share').count()['prize']
plt.figure()
prizes_by_share.plot.pie();
print('The percentages are: {}'.format(100*prizes_by_share/prizes_by_share.sum()))
# Out:
# <img src="data:image/png;base64,..." width="640">
# The percentages are: prize_share
# 1/1    37.760703
# 1/2    33.589462
# 1/3    22.063666
# 1/4     6.586169
# Name: prize, dtype: float64

# %% [markdown]
# # Problem 6
#
# Determine how many males and females won the prize. Does the sum of male and female prizes add up to the total entries? If not, why?
#
# On the same graph make histograms for the number of males and females that won the prize each year.

# %%
print(data.groupby('sex').count()['prize'])
print('The sum of male and female prizes do not add up to the total entries because there are entries with Nan for their sex')
plt.figure()
plt.hist(data[data['sex'] == 'Male']['year'], bins = 20)
plt.hist(data[data['sex'] == 'Female']['year'], bins = 20)
plt.legend(['Male', 'Female']);
# Out:
# sex
# Female     49
# Male      836
# Name: prize, dtype: int64
# The sum of male and female prizes do not add up to the total entries because there are entries with Nan for their sex
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Problem 7
#
# How many prizes were won by those whose birth country was United States of America?

# %%
print('{} prizes were worn by those whose birth country was the United States'.format(data[data['birth_country'] == 'United States of America'].count()['prize']))
# Out:
# 259 prizes were worn by those whose birth country was the United States

# %% [markdown]
# # Problem 8
#
# Determine the age that each of the prize winners was when they won the prize. Find the youngest and oldest to win the prize. Find the mean age to win the prize, and the standard deviation of it. Make a histogram of the age each person was when they won the prize.
#
# ### Hint: You can use Pandas DatetimeIndex method to extract the year from the date format yyyy-mm-dd
# > pd.DatetimeIndex(date).year
#
# Where *date* is given in a formate like year-month-day, the above will return the year, hence the *.year* in the call above. Use 'shit+tab' on pandas.DatetimeIndex to learn more.

# %%
age = data['year']-pd.DatetimeIndex(data['birth_date']).year
youngest_winner = data.iloc[age.idxmin()]
oldest_winner = data.iloc[age.idxmax()]
print('The youngest winner was {0}\nThe oldest winner was {1}'.format(youngest_winner['full_name'],oldest_winner['full_name']))
# Out:
# The youngest winner was Malala Yousafzai
# The oldest winner was Leonid Hurwicz

# %%
mean_age = age.mean()
std = age.std()
print('The mean age is {0}\nThe standard deviation is {1}'.format(mean_age, std))
# Out:
# The mean age is 59.453001132502834
# The standard deviation is 12.39929042786365

# %%
plt.figure()
plt.hist(age)
plt.title('Age when Received the Nobel Prize');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Problem 9
#
# Make a copy of the current DataFrame. Then drop the column *lauret_id* from the copied DataFrame (do this inplace so this column is gone).

# %%
copy = data.copy()

# %%
copy.drop('laureate_id', 'columns', inplace = True)

# %% [markdown]
# # Problem 10
#
# Add the age column you calculated in Problem 8 to the DataFrame.

# %%
copy['age'] = age
